# %% [markdown]
# ###### This is written in Markdown Format
#
# # 🔴 DECI AI Level 3 Second Term Project.
#
# ### The next cell which registers all the dataframes (which are from the .json file and the .db file).

# %%
# Please Ignore the .venv file which is required for a virtual python enviroment (since i'm using linux for now)
# Please Ignore all of the commented code since i was experimenting with the ways that i could make it shorter


#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
# DECI AI Level 3 Second Term Project                              IMPORTING MODULES :]                                                              Made By Mostafa Ashraf Kamel

# Check of install Packages
# Check if required packages are installed
try:
    import pandas
    import matplotlib.pyplot
    import lxml
except ImportError as e:
    import sys
    import subprocess
    import time
    # List of packages to install
    # 'sqlite3' is excluded because it is already built into Python's standard library
    PACKAGES = ["pandas", "matplotlib", "lxml"]

    def loading_circle(duration=2):
        """Display a loading circle animation."""
        frames = ['|', '/', '-', '\\']
        end_time = time.time() + duration
        frame_index = 0
        
        while time.time() < end_time:
            sys.stdout.write(f'\r{frames[frame_index]}')
            sys.stdout.flush()
            frame_index = (frame_index + 1) % len(frames)
            time.sleep(0.1)
        
        sys.stdout.write('\rDone! ::: ')
        sys.stdout.flush()

    def install_packages():
        tasks = [
            ("Checking pip installation", 2),
            ("Installing pandas", 2),
            ("Installing matplotlib", 2),
            ("Installing lxml", 2)
        ]
        print(":Info: Starting package installation...\n")
        
        for task_name, duration in tasks:
            print(f":Info: {task_name}...", end=" ")
            try:
                loading_circle(duration)
                print(f"[✓] {task_name} completed!\n")
            except Exception as e:
                print(f"\033[91m[✗] {task_name} failed: {e}\033[0m\n")

    if __name__ == "__main__":
        try:
            install_packages()
        except KeyboardInterrupt:
            print("\n\n\033[91m[✗] Installation interrupted by user.\033[0m")
            sys.exit(1)

import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
# DECI AI Level 3 Second Term Project                             IMPORTING DATAFRAMES :]                                                            Made By Mostafa Ashraf Kamel


conn = sqlite3.connect("../../31008170105078-Library/City Database.db") # Connects to the database on the system
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;",conn) # Reads The database which contains the books and the author the Orders the database From A to Z and in Ascending order.
table_name = tables.iloc[0, 0]
df_db = pd.read_sql_query(f"SELECT * FROM {table_name}", conn) # Makes the dataframe based on the Arranged Table
conn.close()
print("Database Data (Which is Related to the Authors)\n")
print(df_db)
print()

# Checks if the Table is empty if you hadn't changed the directory
#if tables.empty:
#    print("No tables found in the database")
#    df = pd.DataFrame()
#else:
#    table_name = tables.iloc[0, 0]
#    df = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)
print("API Data (Which is related to how much books the customenrs had borrowed)\n")
df_json = pd.read_json("/home/mostafa/Desktop/31008170105078-Library/City API.json")
for column in df_json:
    df_json[column] = df_json[column].sort_values(ascending=True)

print(df_json)
print()


print("Library Data (Which is related to the books that are borrowed)\n")

tables_html = pd.read_html("/home/mostafa/Desktop/31008170105078-Library/City Library.html")
df_html = tables_html[0]
print(df_html)
print("\nEnd Of Code")

#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
# DECI AI Level 3 Second Term Project                                 END OF CODE :]                                                                 Made By Mostafa Ashraf Kamel
# Out:
# Database Data (Which is Related to the Authors)
#
#     book_id                    title          author
# 0       501          The Silver Kite   Amina Darwish
# 1       502           Desert Compass   Amina Darwish
# 2       503        The Lantern Maker    Adel Roushdy
# 3       504      Rooftop Astronomers    Adel Roushdy
# 4       505      Letters to the Nile       Aya Hafez
# 5       506      The Paper Boat Club       Aya Hafez
# 6       507    Fossils and Fireflies     Dalia Serry
# 7       508    The Quiet Observatory     Dalia Serry
# 8       509      Marbles and Mirrors     Diaa Sultan
# 9       510    The Missing Metronome     Diaa Sultan
# 10      511     Winter in Alexandria    Farida Anwar
# 11      512   The Cartographer's Cat    Farida Anwar
# 12      513   Circuits for Beginners    Galal Mounir
# 13      514    The Robot in Row Nine    Galal Mounir
# 14      515       Songs of the Oasis      Hoda Bakry
# 15      516  The Beekeeper's Almanac      Hoda Bakry
# 16      517  Shadows on the Corniche     Hani Nagati
# 17      518     The Ninth Lighthouse     Hani Nagati
# 18      519         Kites Over Cairo  Jasmine Wahdan
# 19      520     The Copper Telescope  Jasmine Wahdan
# 20      521    A Garden of Equations      Karim Elwy
# 21      522      The Puzzle Merchant      Karim Elwy
# 22      523    Footsteps in the Dust    Laila Shokry
# 23      524    The Weaver's Daughter    Laila Shokry
# 24      525     Storms and Sailboats   Mahmoud Rafei
# 25      526    The Clockwork Orchard   Mahmoud Rafei
# 26      527     Notes from the Delta  Mona Kholoussy
# 27      528        The Glass Beehive  Mona Kholoussy
# 28      529   Riddles of the Red Sea    Sara Tantawy
# 29      530        The Sandstone Key    Sara Tantawy
# 30      531    Voices in the Library     Samir Zohdy
# 31      532        The Last Bookmark     Samir Zohdy
#
# API Data (Which is related to how much books the customenrs had borrowed)
#
#     book_id            genre  pages  publication_year            publisher
# 0       501        Adventure    128            2017.0           Nile Press
# 1       502        Adventure    109            2018.0          Delta House
# 2       503       Historical    259               NaN           Nile Press
# 3       504          Science    319            2009.0  Cairo Young Readers
# 4       505       Historical    216            2024.0          Oasis Books
# 5       506       Friendship    183               NaN           Nile Press
# 6       507          Science    160            2024.0           Nile Press
# 7       508          Science    306            2011.0          Oasis Books
# 8       509          Mystery    221            2011.0           Nile Press
# 9       510          Mystery    134            2013.0  Cairo Young Readers
# 10      511       Historical    117            2016.0           Nile Press
# 11      512        Adventure    238            2022.0          Delta House
# 12      513          Science    294            2021.0          Oasis Books
# 13      514  Science Fiction    328            2023.0  Cairo Young Readers
# 14      515           Poetry    316            2022.0  Cairo Young Readers
# 15      516           Nature    241            2010.0           Nile Press
# 16      517          Mystery    338            2015.0          Delta House
# 17      518        Adventure    163            2011.0          Delta House
# 18      519       Friendship    157            2014.0           Nile Press
# 19      520  Science Fiction    136            2009.0          Oasis Books
# 20      521          Science    211            2024.0  Cairo Young Readers
# 21      522          Mystery    104            2016.0  Cairo Young Readers
# 22      523       Historical    276            2018.0          Oasis Books
# 23      524       Historical    114            2016.0  Cairo Young Readers
# 24      525        Adventure    297            2015.0          Oasis Books
# 25      526  Science Fiction    125            2016.0          Delta House
# 26      527           Nature    328            2017.0          Delta House
# 27      528           Nature    114            2010.0          Delta House
# 28      529          Mystery    298               NaN  Cairo Young Readers
# 29      530        Adventure    208            2012.0          Oasis Books
# 30      531       Friendship    272            2018.0          Oasis Books
# 31      532       Friendship    337            2017.0          Oasis Books
#
# Library Data (Which is related to the books that are borrowed)
#
#     Member ID  Book ID Checkout Date
# 0        1026      522    2025-07-11
# 1        1049      520    2025-07-11
# 2        1062      525    2025-07-05
# 3        1065      520    2025-07-07
# 4        1104      515    2025-07-07
# 5        1009      503    2025-07-09
# 6        1063      522    2025-07-07
# 7        1022      511    2025-07-12
# 8        1029      523    2025-07-09
# 9        1201      509    2025-07-10
# 10       1005      513    2025-07-10
# 11       1104      526    2025-07-05
# 12       1058      518    2025-07-08
# 13       1002      521    2025-07-08
# 14       1150      530    2025-07-10
# 15       1041      504    2025-07-05
# 16       1055      526    2025-07-11
# 17       1061      513    2025-07-06
# 18       1012      509    2025-07-11
# 19       1007      510    2025-07-07
# 20       1073      530    2025-07-07
# 21       1003      501    2025-07-08
# 22       1017      507    2025-07-11
# 23       1061      504    2025-07-06
# 24       1201      523    2025-07-08
# 25       1041      512    2025-07-06
#
# End Of Code

# %% [markdown]
# # 1️⃣ Answering The First SQL Question Which is How Many Checkouts Per Member

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
# DECI AI Level 3 Second Term Project                                 First SubTask :]                                                               Made By Mostafa Ashraf Kamel

df_html_Member_ID_sorted = df_html.sort_values(by="Member ID",ascending=True) # Make a sorted Version of the html dataframe by Member ID
print(df_html_Member_ID_sorted)
print()

member_count = df_html_Member_ID_sorted["Member ID"].value_counts().sort_index() # Make It Sorted By Member ID
print("Checkout Per Member ID :\n")

# Checks How Many Checkout(s) Per Member
for member_id, count in member_count.items():
    print(f"Member No.'{member_id}': {count} checkout(s)")

#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
# DECI AI Level 3 Second Term Project                                 END OF CODE :]                                                                 Made By Mostafa Ashraf Kamel

# %% [markdown]
# # 2️⃣ Answering The Second SQL Question Which is Which books in The Database Have Authors Whose Names Contain The Chosen Letter or Pattern?

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
# DECI AI Level 3 Second Term Project                                 Second SubTask :]                                                              Made By Mostafa Ashraf Kamel


pattern = input("Enter a letter or pattern to search by author name: ").strip() # Acts like a Search Bar for The Author

if pattern: # Checks If user had entered any values
    author_col = next((col for col in df_db.columns if "author" in col.lower()), None) # Prints The colums which has the author in it
    title_col = next((col for col in df_db.columns if "title" in col.lower() or "book" in col.lower()), None) # Prints the columns which has the book's title 

    if author_col is None: # Checks if there's any author within the user's serach
        raise ValueError("No Results")

    matches = df_db[df_db[author_col].astype(str).str.contains(pattern, case=False, na=False)] # Filter all rows whose author contains the pattern

    print(f"Books whose author contains '{pattern}':")
    if title_col is not None:
        print(matches[[title_col, author_col]].reset_index(drop=True))
    else:
        print(matches.reset_index(drop=True))
else:
    print("No pattern entered.")

#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
# DECI AI Level 3 Second Term Project                                 END OF CODE :]                                                                 Made By Mostafa Ashraf Kamel

# %% [markdown]
# # 3️⃣ Answering The Third SQL Question Which is What are the Most Books Borrowed By Members

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
# DECI AI Level 3 Second Term Project                                 Third SubTask :]                                                               Made By Mostafa Ashraf Kamel

df_html_Book_ID_sorted = df_html.sort_values(by="Book ID",ascending=True) # Make a sorted Version of the html dataframe by Book ID
print(df_html_Book_ID_sorted)

Book_count = df_html_Book_ID_sorted["Book ID"].value_counts().sort_index() # Make It Sorted By Book ID
print("Book ID Per Member :\n")

# Checks How Many Books(s) Per Member
#for Book_id, count in Book_count.items():
#    print(f"Book No.'{Book_id}': {count} Member(s)")

# Prints The Top 5 one
print("\nTop 5 Most Borrowed Books:")
top_5_books = Book_count.nlargest(5)
for book_id, count in top_5_books.items():
    print(f"Book No.'{book_id}': {count} Member(s)")

#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
# DECI AI Level 3 Second Term Project                                 END OF CODE :]                                                                 Made By Mostafa Ashraf Kamel

# %% [markdown]
# # 4️⃣ Answering The Fourth SQL Question Which is What are the Members with the Most Borrowed Books

# %%
#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
# DECI AI Level 3 Second Term Project                                Fourth SubTask :]                                                              Made By Mostafa Ashraf Kamel

# Now Let's do a Merged Data Frame

df_Merged = df_html.merge(df_db, left_on='Book ID', right_on='book_id', how='left').merge(df_json, on='book_id', how='left') # Merges The Data Frames all together into one
df_Merged_Mode = df_Merged[0:10].mode() # A Clever Way to Get the Mode For Every Column By using the Mode.
df_Merged_Cleaned = df_Merged.fillna(df_Merged_Mode.iloc[0]) # And Then Targetting the Empty Cell in the DataFrame.
print(df_Merged_Cleaned) # prints it so it You check if the dataframe is working/merged.
df_Merged_Cleaned.to_csv("task 1 cleaned.csv") # Outputting them into a merged dataframe and cleaning them

# !!! IMPORTANT !!! The Syntax For the DataFrame When printed is:
#                   1. The HTML DataFrame (Member ID, Book ID and Checkout Date columns).
#                   2. The SQL Database DataFrame (book_id, title, and author columns).
#                   3. The JSON DataFrame (genre, pages an publication_year) columns.

# Print top 5 members with the most borrowed books.
member_borrow_counts = df_html["Member ID"].value_counts().sort_values(ascending=False) # sorts them descendingly (From The Greatest to the Smallest).

# Now It just prints them.
print("\nTop 10 Members with the Most Borrowed Books:")
top_10_members = member_borrow_counts.head(10)
print(top_10_members)

# And Checks For Every Member ID Book Count.
# for member_id, count in top_5_members.items():
#     print(f"Member No.'{member_id}': {count} book(s)")

#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
# DECI AI Level 3 Second Term Project                                 END OF CODE :]                                                                 Made By Mostafa Ashraf Kamel
# Out:
#     Member ID  Book ID Checkout Date  book_id                   title  \
# 0        1026      522    2025-07-11      522     The Puzzle Merchant
# 1        1049      520    2025-07-11      520    The Copper Telescope
# 2        1062      525    2025-07-05      525    Storms and Sailboats
# 3        1065      520    2025-07-07      520    The Copper Telescope
# 4        1104      515    2025-07-07      515      Songs of the Oasis
# 5        1009      503    2025-07-09      503       The Lantern Maker
# 6        1063      522    2025-07-07      522     The Puzzle Merchant
# 7        1022      511    2025-07-12      511    Winter in Alexandria
# 8        1029      523    2025-07-09      523   Footsteps in the Dust
# 9        1201      509    2025-07-10      509     Marbles and Mirrors
# 10       1005      513    2025-07-10      513  Circuits for Beginners
# 11       1104      526    2025-07-05      526   The Clockwork Orchard
# 12       1058      518    2025-07-08      518    The Ninth Lighthouse
# 13       1002      521    2025-07-08      521   A Garden of Equations
# 14       1150      530    2025-07-10      530       The Sandstone Key
# 15       1041      504    2025-07-05      504     Rooftop Astronomers
# 16       1055      526    2025-07-11      526   The Clockwork Orchard
# 17       1061      513    2025-07-06      513  Circuits for Beginners
# 18       1012      509    2025-07-11      509     Marbles and Mirrors
# 19       1007      510    2025-07-07      510   The Missing Metronome
# 20       1073      530    2025-07-07      530       The Sandstone Key
# 21       1003      501    2025-07-08      501         The Silver Kite
# 22       1017      507    2025-07-11      507   Fossils and Fireflies
# 23       1061      504    2025-07-06      504     Rooftop Astronomers
# 24       1201      523    2025-07-08      523   Footsteps in the Dust
# 25       1041      512    2025-07-06      512  The Cartographer's Cat
#
#             author            genre  pages  publication_year  \
# 0       Karim Elwy          Mystery    104            2016.0
# 1   Jasmine Wahdan  Science Fiction    136            2009.0
# 2    Mahmoud Rafei        Adventure    297            2015.0
# 3   Jasmine Wahdan  Science Fiction    136            2009.0
# 4       Hoda Bakry           Poetry    316            2022.0
# 5     Adel Roushdy       Historical    259            2016.0
# 6       Karim Elwy          Mystery    104            2016.0
# 7     Farida Anwar       Historical    117            2016.0
# 8     Laila Shokry       Historical    276            2018.0
# 9      Diaa Sultan          Mystery    221            2011.0
# 10    Galal Mounir          Science    294            2021.0
# 11   Mahmoud Rafei  Science Fiction    125            2016.0
# 12     Hani Nagati        Adventure    163            2011.0
# 13      Karim Elwy          Science    211            2024.0
# 14    Sara Tantawy        Adventure    208            2012.0
# 15    Adel Roushdy          Science    319            2009.0
# 16   Mahmoud Rafei  Science Fiction    125            2016.0
# 17    Galal Mounir          Science    294            2021.0
# 18     Diaa Sultan          Mystery    221            2011.0
# 19     Diaa Sultan          Mystery    134            2013.0
# 20    Sara Tantawy        Adventure    208            2012.0
# 21   Amina Darwish        Adventure    128            2017.0
# 22     Dalia Serry          Science    160            2024.0
# 23    Adel Roushdy          Science    319            2009.0
# 24    Laila Shokry       Historical    276            2018.0
# 25    Farida Anwar        Adventure    238            2022.0
#
#               publisher
# 0   Cairo Young Readers
# 1           Oasis Books
# 2           Oasis Books
# 3           Oasis Books
# 4   Cairo Young Readers
# 5            Nile Press
# 6   Cairo Young Readers
# 7            Nile Press
# 8           Oasis Books
# 9            Nile Press
# 10          Oasis Books
# 11          Delta House
# 12          Delta House
# 13  Cairo Young Readers
# 14          Oasis Books
# 15  Cairo Young Readers
# 16          Delta House
# 17          Oasis Books
# 18           Nile Press
# 19  Cairo Young Readers
# 20          Oasis Books
# 21           Nile Press
# 22           Nile Press
# 23  Cairo Young Readers
# 24          Oasis Books
# 25          Delta House
#
# Top 10 Members with the Most Borrowed Books:
# Member ID
# 1104    2
# 1201    2
# 1041    2
# 1061    2
# 1026    1
# 1049    1
# 1062    1
# 1065    1
# 1009    1
# 1063    1
# Name: count, dtype: int64

# %% [markdown]
# # 5️⃣ Answering The Fifth SQL Question Which is Getting Checkouts, Second Set of 10 Right after The Top 10 Most Recent
# #### (Which is From 11 To 20)

# %%
#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
# DECI AI Level 3 Second Term Project                                 FifTh SubTask :]                                                              Made By Mostafa Ashraf Kamel

# Getting The Second Set of 10
# We'll use the Cleaned DataFrame

df_Second_10 = df_Merged_Cleaned[10:20]
print(df_Second_10)
#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
# DECI AI Level 3 Second Term Project                                 END OF CODE :]                                                                 Made By Mostafa Ashraf Kamel
# Out:
#     Member ID  Book ID Checkout Date  book_id                   title  \
# 10       1005      513    2025-07-10      513  Circuits for Beginners
# 11       1104      526    2025-07-05      526   The Clockwork Orchard
# 12       1058      518    2025-07-08      518    The Ninth Lighthouse
# 13       1002      521    2025-07-08      521   A Garden of Equations
# 14       1150      530    2025-07-10      530       The Sandstone Key
# 15       1041      504    2025-07-05      504     Rooftop Astronomers
# 16       1055      526    2025-07-11      526   The Clockwork Orchard
# 17       1061      513    2025-07-06      513  Circuits for Beginners
# 18       1012      509    2025-07-11      509     Marbles and Mirrors
# 19       1007      510    2025-07-07      510   The Missing Metronome
#
#            author            genre  pages  publication_year  \
# 10   Galal Mounir          Science    294            2021.0
# 11  Mahmoud Rafei  Science Fiction    125            2016.0
# 12    Hani Nagati        Adventure    163            2011.0
# 13     Karim Elwy          Science    211            2024.0
# 14   Sara Tantawy        Adventure    208            2012.0
# 15   Adel Roushdy          Science    319            2009.0
# 16  Mahmoud Rafei  Science Fiction    125            2016.0
# 17   Galal Mounir          Science    294            2021.0
# 18    Diaa Sultan          Mystery    221            2011.0
# 19    Diaa Sultan          Mystery    134            2013.0
#
#               publisher
# 10          Oasis Books
# 11          Delta House
# 12          Delta House
# 13  Cairo Young Readers
# 14          Oasis Books
# 15  Cairo Young Readers
# 16          Delta House
# 17          Oasis Books
# 18           Nile Press
# 19  Cairo Young Readers
